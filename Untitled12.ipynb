# %% [markdown]
# <a href="https://colab.research.google.com/github/nehasharma8001/Machine-Learning-/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/Salary_Dataset.csv')
df.head()
country_dummy=pd.get_dummies(df['country'])
dataset=pd.concat([df, country_dummy],axis = 1)
dataset.drop('country',axis = 1, inplace = True)
dataset = dataset[['Australia','Canada','Dubai','USA','YearsExperience','Salary','Purchased']]
dataset.head()
# Out:
#    Australia  Canada  Dubai    USA  YearsExperience   Salary Purchased
# 0      False   False   True  False              1.1  39343.0        No
# 1      False    True  False  False              1.3  46205.0       Yes
# 2      False    True  False  False              1.5  37731.0        No
# 3      False    True  False  False              2.0  43525.0        No
# 4      False   False  False   True              2.2  39891.0        No
