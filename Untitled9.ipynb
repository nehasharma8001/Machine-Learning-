# %% [markdown]
# <a href="https://colab.research.google.com/github/nehasharma8001/Machine-Learning-/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = [10,20,30,40,50]
s = pd.Series(data)

print("Pandas Series:")
print(s)
# Out:
# Pandas Series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd
data = {  "Age":[18,20,22,24,26],
          "Marks":[65,70,75,80,85],
          "Result":[0,0,1,1,1]
       }
df = pd.DataFrame(data)

print("Record:")
print(df)
# Out:
# Record:
#    Age  Marks  Result
# 0   18     65       0
# 1   20     70       0
# 2   22     75       1
# 3   24     80       1
# 4   26     85       1

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
print(df)
df.iloc[11:21,4:7]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...
