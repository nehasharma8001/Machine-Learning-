# %% [markdown]
# <a href="https://colab.research.google.com/github/nehasharma8001/Machine-Learning-/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

X = np.array([6,7,8,9,10]).reshape(-1,1)
y = np.array([3,4,5,7,8])

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mse)
r2 =r2_score(y, y_pred)

print("Model Coefficient (Slope):" , model.coef_[0])
print("Model Intercept:", model.intercept_)

print("\nPerformance Metrics:")
print("MSE:", mse)
print("MAE:", mae)
print("RMSE:", rmse)
print("R2 Score:", r2)

plt.scatter(X,y, color="blue",label="Actual Data")
plt.plot(X, y_pred, color="red", label="Regression Line")
plt.xlabel("House Size")
plt.ylabel("Rent")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()
# Out:
# Model Coefficient (Slope): 1.3
# Model Intercept: -5.0
#
# Performance Metrics:
# MSE: 0.05999999999999985
# MAE: 0.19999999999999965
# RMSE: 0.24494897427831752
# R2 Score: 0.9825581395348838

# %%
import numpy as np

def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 1000
  n = len(x)
  learning_rate = 0.08

  for i in range (iterations):
    y_predicted = m_curr*x + b_curr
    cost = (1/n) *sum([val**2 for val in (y-y_predicted)])
    md = -(2/n)*sum(x*(y-y_predicted))
    bd = -(2/n)*sum(y-y_predicted)
    m_curr = m_curr - learning_rate * md
    b_curr = b_curr - learning_rate * bd
    print ("m {},b{},cost{} iteration {}".format(m_curr,b_curr,cost,i))

    x = np.array([1,2,3,4,5])
    y = np.array([5,7,9,11,13])

    gradient_descent(x,y)
